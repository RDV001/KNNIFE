# %% [markdown]
# Import

# %%
import json
import numpy as np
import pandas as pd
from pathlib import Path

from causRCA_utils import *

# %% [markdown]
# Paths

# %%
fault_records  = load_fault_records()
normal_records = load_normal_records()
build_datasets(fault_records, normal_records)
# Out:
#   Fault records loaded : 100
#   Normal records loaded: 170
# ['diag_1' 'diag_10' 'diag_2' 'diag_3' 'diag_4' 'diag_5' 'diag_6' 'diag_7'
#  'diag_8' 'diag_9']
# [10]
# [5, 9, 12]
# [9]
# [9, 10]
# [10, 61, 70, 66, 67]
# [9]
# [10, 11]
# [9]
# [9, 11]
# [59, 7, 11]
