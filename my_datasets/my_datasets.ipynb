# %%
import __init__

import matplotlib.pyplot as plt

# %%
for dataset_name in __init__.datasets_names:
    data_dict = __init__.load(dataset_name)
    X = data_dict['X']
    y = data_dict['y']
    name = data_dict['name']
    contamination = y.mean()
    print(f"DATASET: {name} | X: {X.shape} | contamination: {100*contamination:.2f}%")
# Out:
# DATASET: wine | X: (129, 13) | contamination: 7.75%
# DATASET: vertebral | X: (240, 6) | contamination: 12.50%
# DATASET: ionosphere | X: (351, 33) | contamination: 35.90%
# DATASET: wbc | X: (378, 30) | contamination: 5.56%
# DATASET: breastw | X: (683, 9) | contamination: 34.99%
# DATASET: pima | X: (768, 8) | contamination: 34.90%
# DATASET: vowels | X: (1456, 12) | contamination: 3.43%
# DATASET: letter | X: (1600, 32) | contamination: 6.25%
# DATASET: cardio | X: (1831, 21) | contamination: 9.61%
# DATASET: thyroid | X: (3772, 6) | contamination: 2.47%
# DATASET: optdigits | X: (5216, 64) | contamination: 2.88%
# DATASET: satimage-2 | X: (5803, 36) | contamination: 1.22%
# DATASET: satellite | X: (6435, 36) | contamination: 31.64%
# DATASET: pendigits | X: (6870, 16) | contamination: 2.27%
# DATASET: annthyroid | X: (7200, 6) | contamination: 7.42%
# DATASET: mammography | X: (11183, 6) | contamination: 2.32%
# DATASET: bisect | X: (1100, 6) | contamination: 9.09%
# ...

# %%
__init__.dataset_dim_hist("bisect", bins=50, scale=True, scale_hist=False)
